# %%
from glob import glob
from datetime import datetime, timedelta
import pandas as pd

# %%
def read_wearable(file_path, device):
    data = pd.read_csv(file_path, usecols=[device + ' Time', device + ' Magnitude'], parse_dates=[device + ' Time'], infer_datetime_format = True).dropna()
    data[device + ' Time'] = data[device + ' Time'].apply(lambda x: x.replace(microsecond=0))
    return data

# %%
def mad(a_df):
    return (a_df - a_df.mean()).abs().mean()

# %%
def calc_mad(some_data, device):
    some_data = some_data.groupby(device + ' Time').agg(mad).reset_index()
    some_data.columns=[device + ' Time', device + ' MAD']
    return some_data

# %%
def read_metric(file_path):
    data = pd.read_csv(file_path, parse_dates=['Time'], infer_datetime_format=True)
    return data

# %%
def read_apple(file_path):
    data = pd.read_csv(file_path, parse_dates=['Apple Time'], infer_datetime_format=True)
    return data

# %% [markdown]
# ## Run code to process Actigraph

# %%
old_metrics_dir = "C:/Users/sambit/Desktop/Actiheart/Agg_Metrics/"
old_metrics = glob(old_metrics_dir + "2501*")
raw_data_dir = "V:/ACOI/R01 - W4K/3_PA protocol/1_Participants/"
new_metrics_dir = "C:/Users/sambit/Desktop/Actiheart/New_Agg_Metrics/"

# %%
i = 1
device='Actigraph'

for file in old_metrics:
    try:
        part_num = file[len(old_metrics_dir):len(old_metrics_dir)+4]
        print(f'{part_num} {i}/{len(old_metrics)}')
        raw_path = raw_data_dir + part_num + "/" + part_num + "_aligned.csv"
        accel_data = read_wearable(raw_path, device)
        mad_data = calc_mad(accel_data, device)
        metrics = read_metric(file)
        metrics[device + " MAD"] = mad_data[device + ' MAD']
        metrics.to_csv(new_metrics_dir + part_num + ".csv")
    except:pass
    i += 1
# Out:
# 2501 1/1

# %% [markdown]
# ## Run code to process apple

# %%
old_metrics_dir = "C:/Users/sambit/Desktop/Apple/Agg_Metrics/"
old_metrics = glob(old_metrics_dir + "[0-9][0-9][0-9][0-9]*")
raw_data_dir = "V:/ACOI/R01 - W4K/3_PA protocol/1_Participants/"
new_metrics_dir = "C:/Users/sambit/Desktop/Apple/New_Agg_Metrics/"
old_metrics
# Out:
# ['C:/Users/sambit/Desktop/Apple/Agg_Metrics\\0118_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\0231_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\0444_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\0601_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\0618_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\0632_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\0695_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\0967_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\1779_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\1854_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\1974_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\1991_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2007_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2069_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2113_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2186_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2187_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2271_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2272_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2321_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2355_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2433_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2453_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2454_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2455_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2456_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2457_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2458_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2470_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2471_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2473_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2474_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2475_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2476_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2479_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2480_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2495_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2496_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2497_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2498_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2499_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2500_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2501_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2502_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2503_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2504_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2505_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2506_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2507_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2508_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2517_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2525_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2531_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2532_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2533_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2540_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2541_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2542_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2543_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2544_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2545_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2546_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2557_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2558_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2559_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2560_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2566_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2576_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2584_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2588_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2589_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2601_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2604_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2605_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2611_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2612_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2613_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2628_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2629_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2630_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2631_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2639_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2640_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2641_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2642_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2643_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2644_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2645_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2646_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2647_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2648_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2649_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2650_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2651_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2657_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2662_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2663_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2664_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2665_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2671_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2676_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2679_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2684_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2685_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2688_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2692_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2706_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2710_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2711_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2753_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2774_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2775_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2776_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2778_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2779_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2782_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2783_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2790_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2794_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2795_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2796_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2797_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2798_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2801_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2812_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2813_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2814_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2815_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2819_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2820_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2821_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2822_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2823_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2988_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2990_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2993_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2995_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2999_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3057_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3058_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3059_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3060_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3160_agg_metrics.csv']

# %%
old_metrics = old_metrics[51:]
old_metrics
# Out:
# ['C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2684_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2685_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2688_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2692_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2706_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2710_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2711_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2753_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2774_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2775_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2776_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2778_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2779_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2782_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2783_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2790_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2794_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2795_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2796_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2797_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2798_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2801_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2812_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2813_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2814_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2815_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2819_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2820_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2821_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2822_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2823_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2988_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2990_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2993_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2995_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\2999_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3057_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3058_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3059_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3060_agg_metrics.csv',
#  'C:/Users/sambit/Desktop/Apple/Agg_Metrics\\3160_agg_metrics.csv']

# %%
i = 1
device='Apple'

for file in old_metrics:
    try:
        part_num = file[len(old_metrics_dir):len(old_metrics_dir)+4]
        print(f'{part_num} {i}/{len(old_metrics)}')
        raw_path = raw_data_dir + part_num + "/" + part_num + "_aligned.csv"
        accel_data = read_wearable(raw_path, device)
        mad_data = calc_mad(accel_data, device)
        metrics = read_metric(file)
        metrics[device + " MAD"] = mad_data[device + ' MAD']
        metrics.to_csv(new_metrics_dir + part_num + ".csv")
    except:pass
    i += 1
# Out:
# 0118 1/143
# 0231 2/143
# 0444 3/143
# 0601 4/143
# 0618 5/143
# 0632 6/143
# 0695 7/143
# 0967 8/143
# 1779 9/143
# 1854 10/143
# 1974 11/143
# 1991 12/143
# 2007 13/143
# 2069 14/143
# 2113 15/143
# 2186 16/143
# 2187 17/143
# 2271 18/143
# 2272 19/143
# 2321 20/143
# 2355 21/143
# 2433 22/143
# 2453 23/143
# 2454 24/143
# 2455 25/143
# 2456 26/143
# 2457 27/143
# 2458 28/143
# 2470 29/143
# 2471 30/143
# 2473 31/143
# 2474 32/143
# 2475 33/143
# 2476 34/143
# 2479 35/143
# 2480 36/143
# 2495 37/143
# 2496 38/143
# 2497 39/143
# 2498 40/143
# 2499 41/143
# 2500 42/143
# 2501 43/143
# 2502 44/143
# 2503 45/143
# 2504 46/143
# 2505 47/143
# 2506 48/143
# 2507 49/143
# 2508 50/143
# 2517 51/143
# 2525 52/143
# 2531 53/143
# 2532 54/143
# 2533 55/143
# 2540 56/143
# 2541 57/143
# 2542 58/143
# 2543 59/143
# 2544 60/143
# 2545 61/143
# 2546 62/143
# 2557 63/143
# 2558 64/143
# 2559 65/143
# 2560 66/143
# 2566 67/143
# 2576 68/143
# 2584 69/143
# 2588 70/143
# 2589 71/143
# 2601 72/143
# 2604 73/143
# 2605 74/143
# 2611 75/143
# 2612 76/143
# 2613 77/143
# 2628 78/143
# 2629 79/143
# 2630 80/143
# 2631 81/143
# 2639 82/143
# 2640 83/143
# 2641 84/143
# 2642 85/143
# 2643 86/143
# 2644 87/143
# 2645 88/143
# 2646 89/143
# 2647 90/143
# 2648 91/143
# 2649 92/143
# 2650 93/143
# 2651 94/143
# 2657 95/143
# 2662 96/143
# 2663 97/143
# 2664 98/143
# 2665 99/143
# 2671 100/143
# 2676 101/143
# 2679 102/143
# 2684 103/143
# 2685 104/143
# 2688 105/143
# 2692 106/143
# 2706 107/143
# 2710 108/143
# 2711 109/143
# 2753 110/143
# 2774 111/143
# 2775 112/143
# 2776 113/143
# 2778 114/143
# 2779 115/143
# 2782 116/143
# 2783 117/143
# 2790 118/143
# 2794 119/143
# 2795 120/143
# 2796 121/143
# 2797 122/143
# 2798 123/143
# 2801 124/143
# 2812 125/143
# 2813 126/143
# 2814 127/143
# 2815 128/143
# 2819 129/143
# 2820 130/143
# 2821 131/143
# 2822 132/143
# 2823 133/143
# 2988 134/143
# 2990 135/143
# 2993 136/143
# 2995 137/143
# 2999 138/143
# 3057 139/143
# 3058 140/143
# 3059 141/143
# 3060 142/143
# 3160 143/143

# %% [markdown]
# ## Run Code to Process Garmin

# %%
old_metrics_dir = "C:/Users/sambit/Desktop/Garmin/Agg_Metrics/"
old_metrics = glob(old_metrics_dir + "[0-9][0-9][0-9][0-9]*")
raw_data_dir = "V:/ACOI/R01 - W4K/3_PA protocol/1_Participants/"
new_metrics_dir = "C:/Users/sambit/Desktop/Garmin/New_Agg_Metrics/"

# %%
i = 1
device='Garmin'
for file in old_metrics:
    part_num = file[len(old_metrics_dir):len(old_metrics_dir)+4]
    print(f'{part_num} {i}/{len(old_metrics)}')
    raw_path = raw_data_dir + part_num + "/" + part_num + "_aligned.csv"
    accel_data = read_wearable(raw_path, device)
    mad_data = calc_mad(accel_data, device)
    metrics = read_metric(file)
    metrics[device + " MAD"] = mad_data[device + ' MAD']
    metrics.to_csv(new_metrics_dir + part_num + ".csv")
    i += 1
# Out:
# 0118 1/131
# 0444 2/131
# 0601 3/131
# 0819 4/131
# 0967 5/131
# 1333 6/131
# 1760 7/131
# 1779 8/131
# 1799 9/131
# 1854 10/131
# 1974 11/131
# 1991 12/131
# 2007 13/131
# 2031 14/131
# 2069 15/131
# 2113 16/131
# 2186 17/131
# 2187 18/131
# 2271 19/131
# 2272 20/131
# 2453 21/131
# 2454 22/131
# 2455 23/131
# 2456 24/131
# 2457 25/131
# 2458 26/131
# 2470 27/131
# 2471 28/131
# 2473 29/131
# 2474 30/131
# 2476 31/131
# 2479 32/131
# 2480 33/131
# 2495 34/131
# 2496 35/131
# 2497 36/131
# 2498 37/131
# 2499 38/131
# 2500 39/131
# 2501 40/131
# 2502 41/131
# 2503 42/131
# 2504 43/131
# 2505 44/131
# 2506 45/131
# 2507 46/131
# 2508 47/131
# 2517 48/131
# 2525 49/131
# 2531 50/131
# 2533 51/131
# 2540 52/131
# 2541 53/131
# 2542 54/131
# 2543 55/131
# 2545 56/131
# 2546 57/131
# 2557 58/131
# 2558 59/131
# 2559 60/131
# 2560 61/131
# 2566 62/131
# 2576 63/131
# 2584 64/131
# 2588 65/131
# 2589 66/131
# 2596 67/131
# 2601 68/131
# 2604 69/131
# 2605 70/131
# 2608 71/131
# 2611 72/131
# 2612 73/131
# 2613 74/131
# 2628 75/131
# 2629 76/131
# 2630 77/131
# 2631 78/131
# 2635 79/131
# 2637 80/131
# 2639 81/131
# 2640 82/131
# 2641 83/131
# 2642 84/131
# 2643 85/131
# 2644 86/131
# 2645 87/131
# 2646 88/131
# 2647 89/131
# 2648 90/131
# 2649 91/131
# 2650 92/131
# 2651 93/131
# 2653 94/131
# 2661 95/131
# 2666 96/131
# 2667 97/131
# 2668 98/131
# 2669 99/131
# 2670 100/131
# 2672 101/131
# 2673 102/131
# 2674 103/131
# 2675 104/131
# 2680 105/131
# 2681 106/131
# 2683 107/131
# 2684 108/131
# 2686 109/131
# 2687 110/131
# 2689 111/131
# 2690 112/131
# 2691 113/131
# 2709 114/131
# 2712 115/131
# 2780 116/131
# 2781 117/131
# 2788 118/131
# 2789 119/131
# 2792 120/131
# 2793 121/131
# 2817 122/131
# 2818 123/131
# 2824 124/131
# 2987 125/131
# 2991 126/131
# 3063 127/131
# 3201 128/131
# 3298 129/131
# 3299 130/131
# 9999 131/131

# %% [markdown]
# ## Rune Code to Process Fitbit

# %%
old_metrics_dir = "C:/Users/sambit/Desktop/Fitbit/Agg_Metrics/"
old_metrics = glob(old_metrics_dir + "[0-9][0-9][0-9][0-9]*")
raw_data_dir = "V:/ACOI/R01 - W4K/3_PA protocol/1_Participants/"
new_metrics_dir = "C:/Users/sambit/Desktop/Fitbit/New_Agg_Metrics/"

# %%
i = 1
device='Fitbit'
for file in old_metrics:
    part_num = file[len(old_metrics_dir):len(old_metrics_dir)+4]
    print(f'{part_num} {i}/{len(old_metrics)}')
    raw_path = raw_data_dir + part_num + "/" + part_num + "_aligned.csv"
    accel_data = read_wearable(raw_path, device)
    mad_data = calc_mad(accel_data, device)
    metrics = read_metric(file)
    metrics[device + " MAD"] = mad_data[device + ' MAD']
    metrics.to_csv(new_metrics_dir + part_num + ".csv")
    i += 1
# Out:
# 0231 1/91
# 0618 2/91
# 0632 3/91
# 0695 4/91
# 1333 5/91
# 1760 6/91
# 1772 7/91
# 1799 8/91
# 2031 9/91
# 2321 10/91
# 2433 11/91
# 2532 12/91
# 2596 13/91
# 2635 14/91
# 2637 15/91
# 2653 16/91
# 2657 17/91
# 2661 18/91
# 2662 19/91
# 2663 20/91
# 2664 21/91
# 2665 22/91
# 2666 23/91
# 2667 24/91
# 2668 25/91
# 2669 26/91
# 2670 27/91
# 2671 28/91
# 2672 29/91
# 2673 30/91
# 2674 31/91
# 2675 32/91
# 2676 33/91
# 2680 34/91
# 2681 35/91
# 2683 36/91
# 2685 37/91
# 2686 38/91
# 2687 39/91
# 2688 40/91
# 2689 41/91
# 2690 42/91
# 2691 43/91
# 2706 44/91
# 2709 45/91
# 2711 46/91
# 2712 47/91
# 2753 48/91
# 2775 49/91
# 2778 50/91
# 2780 51/91
# 2781 52/91
# 2782 53/91
# 2788 54/91
# 2789 55/91
# 2790 56/91
# 2792 57/91
# 2793 58/91
# 2794 59/91
# 2795 60/91
# 2797 61/91
# 2798 62/91
# 2801 63/91
# 2812 64/91
# 2813 65/91
# 2814 66/91
# 2815 67/91
# 2816 68/91
# 2817 69/91
# 2818 70/91
# 2819 71/91
# 2820 72/91
# 2821 73/91
# 2822 74/91
# 2823 75/91
# 2824 76/91
# 2987 77/91
# 2988 78/91
# 2989 79/91
# 2990 80/91
# 2991 81/91
# 2993 82/91
# 2995 83/91
# 2996 84/91
# 2999 85/91
# 3058 86/91
# 3059 87/91
# 3060 88/91
# 3063 89/91
# 3200 90/91
# 3201 91/91
