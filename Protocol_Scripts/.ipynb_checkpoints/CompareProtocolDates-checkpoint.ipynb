# %%
import glob
import os.path
import pandas as pd
import math
from datetime import datetime, timedelta

# %%
pa_dir="V:/ACOI/R01 - W4K/4_Free living/Participant Data/"
participants=glob.glob(pa_dir+"[0-9][0-9][0-9][0-9]/")
tracking_sheet = pd.read_excel("V:/ACOI/R01 - W4K/4_Free living/Free-living master tracking.xlsx",skiprows=1)

# %%
cur_par=1
for participant in participants:
    part_id=participant[len(pa_dir):len(pa_dir)+4]
    
    print(f"Participant {part_id} {cur_par}/{len(participants)}")
    print("Camp Data")
    try:
        comparetimes(part_id,"Camp")
    except Exception as error:
        # handle the exception
        print("An exception occurred:", error)
    print("Home Data")
    try:
        comparetimes(part_id,"Home")
    except Exception as error:
        # handle the exception
        print("An exception occurred:", error)
    

            
        
    
    cur_par+=1
# Out:
# Participant 0967 1/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:31 AM
# End time does not match
# Participant 2258 2/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:37 AM
# End time does not match
# Participant 2453 3/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:42 AM
# End time does not match
# Participant 2455 4/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:00 AM
# End time does not match
# Participant 2457 5/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:50 AM
# End time does not match
# Participant 2458 6/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 05:45 AM
# End time does not match
# Participant 2496 7/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:05 AM
# End time does not match
# Participant 2497 8/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:00 AM
# End time does not match
# Participant 2498 9/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:15 AM
# End time does not match
# Participant 2502 10/55
# Camp Data
# Start Time does not Match
# End time matches
# Home Data
# Start Time does not Match
# 06:50 AM
# End time does not match
# Participant 2504 11/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:22 AM
# End time does not match
# Participant 2505 12/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:43 AM
# End time does not match
# Participant 2508 13/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:49 AM
# End time does not match
# Participant 2531 14/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:46 AM
# End time does not match
# Participant 2532 15/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:48 AM
# End time does not match
# Participant 2533 16/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:30 AM
# End time does not match
# Participant 2541 17/55
# Camp Data
# Start Time does not Match
# End time matches
# Home Data
# Start Time does not Match
# 09:19 AM
# End time does not match
# Participant 2544 18/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:21 AM
# End time does not match
# Participant 2559 19/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:50 AM
# End time does not match
# Participant 2561 20/55
# Camp Data
# Start Time does not Match
# End time matches
# Home Data
# Start Time does not Match
# 08:41 AM
# End time does not match
# Participant 2588 21/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start time matches
# 08:41 AM
# End time does not match
# Participant 2643 22/55
# Camp Data
# Start time matches
# End time does not match
# Home Data
# Start Time does not Match
# 07:30 AM
# End time does not match
# Participant 3206 23/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:01 AM
# End time does not match
# Participant 3218 24/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:01 AM
# End time does not match
# Participant 3219 25/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# An exception occurred: 'float' object has no attribute 'strftime'
# Participant 3220 26/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:38 AM
# End time does not match
# Participant 3221 27/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:30 AM
# End time does not match
# Participant 3222 28/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start time matches
# 10:00 AM
# End time matches
# Participant 3223 29/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 06:45 AM
# End time does not match
# Participant 3225 30/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 06:15 AM
# End time does not match
# Participant 3226 31/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 06:15 AM
# End time does not match
# Participant 3227 32/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:02 AM
# End time does not match
# Participant 3228 33/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:30 AM
# End time does not match
# Participant 3229 34/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:09 AM
# End time does not match
# Participant 3230 35/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:08 AM
# End time does not match
# Participant 3231 36/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:40 AM
# End time does not match
# Participant 3234 37/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:10 AM
# End time does not match
# Participant 3236 38/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:40 AM
# End time does not match
# Participant 3238 39/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start time matches
# 10:00 AM
# End time matches
# Participant 3239 40/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:31 AM
# End time does not match
# Participant 3241 41/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:38 AM
# End time does not match
# Participant 3243 42/55
# Camp Data
# Start Time does not Match
# End time matches
# Home Data
# Start time matches
# 10:00 AM
# End time matches
# Participant 3244 43/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:00 AM
# End time does not match
# Participant 3245 44/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 06:15 AM
# End time does not match
# Participant 3246 45/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:27 AM
# End time does not match
# Participant 3247 46/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 07:00 AM
# End time does not match
# Participant 3248 47/55
# Camp Data
# Start Time does not Match
# End time matches
# Home Data
# Start Time does not Match
# 09:45 AM
# End time does not match
# Participant 3249 48/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:52 AM
# End time does not match
# Participant 3255 49/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:10 AM
# End time does not match
# Participant 3256 50/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:44 AM
# End time does not match
# Participant 3257 51/55
# Camp Data
# Start Time does not Match
# End time matches
# Home Data
# Start Time does not Match
# 06:00 AM
# End time does not match
# Participant 3258 52/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 08:38 AM
# End time does not match
# Participant 3276 53/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 09:35 AM
# End time does not match
# Participant 3277 54/55
# Camp Data
# Start Time does not Match
# End time does not match
# Home Data
# Start Time does not Match
# 07:45 AM
# End time does not match
# Participant 3279 55/55
# Camp Data
# Start Time does not Match
# End time matches
# Home Data
# Start Time does not Match
# 09:46 AM
# End time does not match

# %%
def comparetimes(part_id,protocol):
    if protocol=="Camp":      
        start_time = tracking_sheet.loc[tracking_sheet['WDID'] == int(part_id), 'ALL DEVICES ON: CAMP'].iloc[0]
        start_time = start_time.strftime("%I:%M %p")  # Format in 12-hour clock with AM/PM
        end_time = tracking_sheet.loc[tracking_sheet['WDID'] == int(part_id), 'ALL DEVICES OFF: CAMP'].iloc[0]
        end_time = end_time.strftime("%I:%M %p")  # Format in 12-hour clock with AM/PM
        # Read CSV file
        protocol=protocol.lower()
        st_time = pd.read_csv(pa_dir+f"{part_id}/{protocol}/{part_id}_{protocol}_log.csv")
        st_time_datetime = pd.to_datetime(st_time.loc[0, 'Activity_Start'])  # Convert to datetime object
        formatted_st_time = st_time_datetime.strftime('%m/%d/%Y %I:%M %p')  # Format as desired
        if formatted_st_time[-8:] == start_time:
            print("Start time matches")
        else:
            print("Start Time does not Match")
        ed_time_datetime = pd.to_datetime(st_time.iloc[-1, 3])
        formatted_ed_time = ed_time_datetime.strftime('%m/%d/%Y %I:%M %p')
        if formatted_ed_time[-8:] == end_time:
            print("End time matches")
        else:
            print("End time does not match")
    if protocol=="Home":
        start_time = tracking_sheet.loc[tracking_sheet['WDID'] == int(part_id), 'ALL DEVICES ON: HOME'].iloc[0]
        start_time = start_time.strftime("%I:%M %p")  # Format in 12-hour clock with AM/PM
        end_time = tracking_sheet.loc[tracking_sheet['WDID'] == int(part_id), 'ALL DEVICES OFF: HOME'].iloc[0]
        end_time = end_time.strftime("%I:%M %p")  # Format in 12-hour clock with AM/PM
        # Read CSV file
        protocol=protocol.lower()
        st_time = pd.read_csv(pa_dir+f"{part_id}/{protocol}/{part_id}_{protocol}_log.csv")
        st_time_datetime = pd.to_datetime(st_time.iloc[0,0])  # Convert to datetime object
        formatted_st_time = st_time_datetime.strftime('%m/%d/%Y %I:%M %p')  # Format as desired
        if formatted_st_time[-8:] == start_time:
            print("Start time matches")
        else:
            print("Start Time does not Match")
        ed_time_datetime = pd.to_datetime(st_time.iloc[-1, 0])
        formatted_ed_time = ed_time_datetime.strftime('%m/%d/%Y %I:%M %p')
        
        if formatted_ed_time[-8:] == end_time:
            print("End time matches")
        else:
            print("End time does not match")
